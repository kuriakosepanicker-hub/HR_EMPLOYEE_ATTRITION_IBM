# %% [markdown]
# # ETL_Notebook

# %% [markdown]
# ## Objectives
#
# * Fetching the raw employee attrition data of IBM from kaggle and loading it for analysis.
# * Inspect the data set strcucture,shapes,column data types.
# * Performing the data cleaning and pre-processing the data.
# * Handlimg missing values and Duplicates.
# * Transform data where necessary for analysis.
# * Prepare the data dor Exploratory Data Analysis (EDA) and Hypothesis Testing.
# * Save the cleaned data as a new .csv file for further analysis and modelling.
#
# ## Inputs
#
# * Source: IBM HR Analytics Employee Attrition Dataset
#     - Format: CSV
#     - Contains employee demographic, job-related, and performance information.
# * Librarires Required:
#     Numpy and pandas used for data cleaning, data exploration , data analysis and data visualiztion.
#
# ## Outputs
#
# * Write here which files, code or artefacts you generate by the end of the notebook
#
# ## Additional Comments
#
# * If you have any additional comments that don't fit in the previous bullets, please state them here.

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/Users/shiffzz/Documents/Projects/HR_EMPLOYEE_ATTRITION_IBM/jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/Users/shiffzz/Documents/Projects/HR_EMPLOYEE_ATTRITION_IBM'

# %% [markdown]
# # Import libraries and packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Section 1 - Extraction

# %% [markdown]
# Section 1 content

# %%
# Load the csv file.
df_raw = pd.read_csv("Dataset/Raw_Dataset/WA_Fn-UseC_-HR-Employee-Attrition.csv")
print("The dataset has been loaded successfully.")
print(f"shape:{df_raw.shape[0]} rows and {df_raw.shape[1]} columns")
df_raw.head()
# Out:
# The dataset has been loaded successfully.
# shape:1470 rows and 35 columns
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %%
df_raw.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Section 2 - Transformation

# %% [markdown]
# Section 2 content

# %%
#Check for duplicate rows.
print("Duplicate rows found:", df_raw.duplicated().sum())
# Out:
# Duplicate rows found: 0

# %%
# Remove duplicate rows if any exist
df_cleaned = df_raw.drop_duplicates()
df_cleaned.shape
# Out:
# (1470, 35)

# %%
#Check for empty cells (null values)
print("Empty cells found: ", df_cleaned.isnull().sum())
# Out:
# Empty cells found:  Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# ...

# %%
#Print unique values.
print(f"Unique values:\n{df_cleaned.nunique()}")
# Out:
# Unique values:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
df_cleaned.shape
# Out:
# (1470, 35)

# %%
#Dropping Columns that are not useful for analysis as they have only one unique value.
columns_to_drop = ['EmployeeCount', 'Over18', 'StandardHours']
df_cleaned = df_cleaned.drop(columns=columns_to_drop)

# %%
#Checking the columns have been dropped
df_cleaned.shape
# Out:
# (1470, 32)

# %%
#creating a copy of the cleaned dataset to be used for analysis.
df_analysis = df_cleaned.copy()

# %% [markdown]
# # Section 3 - Load

# %% [markdown]
# Section 3 content

# %% [markdown]
# ---

# %% [markdown]
# NOTE

# %% [markdown]
# * You may add as many sections as you want, as long as it supports your project workflow.
# * All notebook's cells should be run top-down (you can't create a dynamic wherein a given point you need to go back to a previous cell to execute some task, like go back to a previous cell and refresh a variable content)

# %% [markdown]
# ---

# %% [markdown]
# # Push files to Repo

# %% [markdown]
# * In cases where you don't need to push files to Repo, you may replace this section with "Conclusions and Next Steps" and state your conclusions and next steps.

# %%
import os
try:
  # create your folder here
  # os.makedirs(name='')
except Exception as e:
  print(e)
# Out:
#   Cell In[8], line 5
#     except Exception as e:
#     ^
# IndentationError: expected an indented block after 'try' statement on line 2
